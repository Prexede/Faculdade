# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from scipy.fftpack import fft, fftfreq

# %% [markdown]
# # Sinais Fundamentais

# %%
### parâmetros do sinal ###

##Amplitude 
A = 1
A1 = 1

##Frequencia 
freq = 0.4
freq1 = 0.05

##Parametros de Sinal
Amostras_ciclo = 1000 

#Tempo inicial
t0 = 0

#Qtd de Periodos
Num_T = 5

#Periodo
T = 1/freq1

#Fator de Modulação
#sobremodulado
u = 1.5
#normal
u1 = 0.5

##Vetor de tempo
t = np.linspace(t0,T*Num_T, Num_T*Amostras_ciclo)

# sinal portador
w = freq
#w = 2.0*np.pi*freq
X = A*np.cos(w*t)

# sinal modulante
w1= freq1
#w1 = 2.0*np.pi*freq1
Y = A1*np.cos(w1*t)

#sinal modulado 
Z = A*(1+(u*Y))*X

# %% [markdown]
# ## Transformada de Fourier

# %%
from scipy.fft import fft, fftfreq

# sampling rate
sr = Amostras_ciclo
# sampling interval

z = fft(Z)
N = len(z)
n = np.arange(N)
T1 = N/sr
f = n/T1 

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(f, np.abs(z), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
# Out:
# Text(0, 0.5, 'FFT Amplitude |X(freq)|')

# %%
# Python example - Fourier transform using numpy.fft method

import numpy as np

import matplotlib.pyplot as plotter




# At what intervals time points are sampled
samplingInterval =  Num_T*Amostras_ciclo

samplingFrequency   = 1/samplingInterval;

# Begin time period of the signals
beginTime           = t0

# End time period of the signals
endTime             = T*Num_T

# Time points

time = np.arange(beginTime, endTime, samplingInterval);

 

# Create two sine waves

amplitude = Z


# Frequency domain representation

fourierTransform = np.fft.fft(amplitude)/len(amplitude)           # Normalize amplitude

fourierTransform = fourierTransform[range(int(len(amplitude)/2))] # Exclude sampling frequency

 

tpCount     = len(amplitude)

values      = np.arange(int(tpCount/2))

timePeriod  = tpCount/samplingFrequency

frequencies = values/timePeriod

 

# Frequency domain representation


plt.plot(frequencies, abs(fourierTransform))

plt.set_xlabel('Frequency')

plt.set_ylabel('Amplitude')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-4b2d3662263b> in <module>
#      53 plt.plot(frequencies, abs(fourierTransform))
#      54
# ---> 55 plt.set_xlabel('Frequency')
#      56
#      57 plt.set_ylabel('Amplitude')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xlabel'

# %% [markdown]
# ## Plotando os Graficos

# %% [markdown]
# ### Sinal Portador

# %%
##Tamanho da Figura 
figure(figsize=(15, 5), dpi=100)

##Cabeçalho
plt.title('Sinal portador')
plt.xlabel('X', fontsize=15)
plt.ylabel('F(X)', fontsize=15)
plt.grid()

##plot linhas traçejadas 
plt.plot([t0,T*Num_T], [0,0], '--')

##plot função 
plt.plot(t,X ,'g--')

##Salvando valores 
plt.savefig(r'C:\Users\carlo\OneDrive\Documentos\GitHub\Faculdade\Principios de Com\Atividade A4\portador.png', dpi = 300)

# %% [markdown]
# ## Sinal Modulante

# %%
##Tamanho da Figura 
figure(figsize=(15, 5), dpi=100)

##Cabeçalho
plt.title('Sinal modulante')
plt.xlabel('X', fontsize=15)
plt.ylabel('F(X)', fontsize=15)
plt.grid()

##plot linhas traçejadas 
plt.plot([t0,T*Num_T], [0,0], '--')

##plot função 
plt.plot(t,Y ,'b:')

##Salvando valores 
plt.savefig(r'C:\Users\carlo\OneDrive\Documentos\GitHub\Faculdade\Principios de Com\Atividade A4\modulante.png', dpi = 300)

# %% [markdown]
# ## Sinal Modulado

# %%
##Tamanho da Figura 
figure(figsize=(15, 5), dpi=100)

##Cabeçalho
plt.title('Funçao Modulada')
plt.xlabel('X', fontsize=15)
plt.ylabel('F(X)', fontsize=15)
plt.grid()

##plot linhas traçejadas 
plt.plot([t0,T*Num_T], [0,0], '--')

##plot função 
plt.plot(t,Z,'r')

##Salvando valores 
plt.savefig(r'C:\Users\carlo\OneDrive\Documentos\GitHub\Faculdade\Principios de Com\Atividade A4\modulado0.png', dpi = 300)
